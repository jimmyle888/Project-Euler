# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Recursion

# def fibonacci(num):
#     if (n <= 1)
#     return 
#     print()

# %%
#Loop
sum = 0
a = 0
b = 1
evenSum = 0

while sum < 4000000:
    sum = a + b
    a = b
    b = sum
    if (b % 2 == 0):
        evenSum = evenSum + b
    print(evenSum)
# Out:
# 0
# 2
# 2
# 2
# 10
# 10
# 10
# 44
# 44
# 44
# 188
# 188
# 188
# 798
# 798
# 798
# 3382
# 3382
# 3382
# 14328
# 14328
# 14328
# 60696
# 60696
# 60696
# 257114
# 257114
# 257114
# 1089154
# 1089154
# 1089154
# 4613732
# 4613732
